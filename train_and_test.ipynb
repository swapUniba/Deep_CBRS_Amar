# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Specify the path:

# %%
cd /content/drive/My Drive/CBRS
# Out:
# /content/drive/My Drive/CBRS

# %% [markdown]
# The train file must match the test file according to the architecture to be evaluated

# %%
#Graph+Bert train
#!python train_model1_graph.py
#!python train_model1_bert.py
#!python train_model1_graph_bert.py
#!python train_model2_conf.py
#!python train_model2_conf2_strategy.py
#!python train_model3_conf2_att.py
#!python train_model3_conf2_strategy_att.py

#Graph+ELMO train Arch 1
#!python train_model1_strategy.py
#Graph+ELMO train Arch 2 Conf 2
#!python train_model2_conf2_strategy.py
#Graph+ELMO train Arch 3 Conf 2 with attention
#!python train_model3_conf2_strategy_att.py

#Graph+GUSE train Arch 1
#!python train_model1_graph_bert.py
#Graph+GUSE train Arch 2 Conf 2
#!python train_model2_conf.py
#Graph+GUSE train Arch 3 Conf 2 with attention
#!python train_model3_conf2_att.py

# %%
#Graph+Bert test
#!python test_model1_graph.py
#!python test_model1_bert.py
#!python test_model1_graph_bert.py
#!python test_model2_conf.py
#!python test_model2_conf2_strategy.py
#!python test_model3_conf2_att.py
#!python test_model3_conf2_strategy_att.py

#Graph+ELMO test Arch 1
#!python test_model1_strategy.py
#Graph+ELMO test Arch 2 Conf 2
#!python test_model2_conf2_strategy.py
#Graph+ELMO test Arch 3 Conf 2 with attention
#!python test_model3_conf2_strategy_att.py

#Graph+GUSE test Arch 1
#!python test_model1_graph_bert.py
#Graph+GUSE test Arch 2 Conf 2
#!python test_model2_conf.py
#Graph+GUSE test Arch 3 Conf 2 with attention
#!python test_model3_conf2_att.py

# %%
# !python evaluate_results.py datasets/movielens/test2id_all_pred.txt predictions

# %%
# !rm -r Results
#!rm Results.zip

# !mkdir Results
# !cp predictions/top_5/predictions_1.tsv Results/predictions_1.tsv
# !cp predictions/top_5/results.tsv Results/results.tsv
# !mv Results/predictions_1.tsv Results/top_5_predictions_1.tsv
# !mv Results/results.tsv Results/top_5_results.tsv
# !cp predictions/top_10/predictions_1.tsv Results/predictions_1.tsv
# !cp predictions/top_10/results.tsv Results/results.tsv
# !mv Results/predictions_1.tsv Results/top_10_predictions_1.tsv
# !mv Results/results.tsv Results/top_10_results.tsv
# !mv results/model.h5 Results/model.h5

# !zip -r "ResultsTRANSDnoStopw.zip" "Results"

from google.colab import files
files.download("ResultsTRANSDnoStopw.zip")
